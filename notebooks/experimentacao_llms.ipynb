# %% [markdown]
# # 🧪 Experimentação com LLMs Open Source
#
# Notebook para testar e comparar diferentes modelos de linguagem no MelâncIA.
#
# **Modelos suportados:**
# - 🤖 OpenAI (GPT-4o-mini, GPT-3.5-turbo)
# - 🦙 Ollama Local (Llama 3.1, Mistral, Phi-3, Gemma)
# - 🤗 HuggingFace (Mistral, Falcon, etc)
#
# **Funcionalidades:**
# - Testar diferentes LLMs
# - Comparar performance
# - Avaliar qualidade de respostas
# - Tracking com MLflow

# %% [markdown]
# ## 📦 Setup

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / 'src'))
print('✅ Setup concluído!')
