# %% [markdown]
# # Obter URLs e salvar em Markdown

# %%
import requests
from bs4 import BeautifulSoup
import os

# URL base do blog
base_url = 'https://www.conectaads.com.br/conteudos/'
pagina = 1
blog_urls = set()  # Usamos um conjunto para evitar duplicatas
paginas_acessadas = 0  # Contador de páginas acessadas

# Pasta de saída para salvar os arquivos Markdown
output_path = "../Input/Blog"
os.makedirs(output_path, exist_ok=True)

def sanitize_filename(name):
    """ Remove caracteres inválidos do nome do arquivo. """
    return "".join(c if c.isalnum() or c in (" ", "-", "_") else "_" for c in name)

# Coletar todas as URLs do blog paginando até a última página
while True:
    # Construir a URL paginada
    url = f'{base_url}page/{pagina}/' if pagina > 1 else base_url
    response = requests.get(url)

    # Verificar se a solicitação foi bem-sucedida
    if response.status_code != 200:
        print(f'❌ Falha ao acessar a página {pagina}. Código de status: {response.status_code}')
        break

    # Atualiza o número de páginas acessadas
    paginas_acessadas += 1

    # Analisar o conteúdo HTML
    soup = BeautifulSoup(response.content, 'html.parser')

    # Encontrar todos os links de postagens
    links = soup.find_all('a', href=True)

    # Filtrar URLs que parecem ser de conteúdos do blog
    excluidos = ['home', 'contato', 'lgpd', 'blog', 'quem-somos', '/page/', 'categoria']
    novos_links = [
        link['href'] for link in links
        if link['href'].startswith('https://www.conectaads.com.br/') and
        not any(ex in link['href'] for ex in excluidos)
    ]

    # Adicionar ao conjunto de URLs
    blog_urls.update(novos_links)

    # Encontrar o link da próxima página corretamente pelo "href"
    next_page_link = soup.find('a', href=lambda href: href and "/page/" in href)

    # Se não houver próxima página, parar o loop
    if not next_page_link:
        break

    pagina += 1  # Ir para a próxima página

# Exibir o total de URLs encontrados e páginas acessadas
print(f"\n🔗 {len(blog_urls)} URLs encontrados em {paginas_acessadas} páginas acessadas.\n")

def extract_and_save(url):
    try:
        page = requests.get(url)
        if page.status_code == 200:
            soup = BeautifulSoup(page.content, 'html.parser')
            
            # Extrair título
            title = soup.find('h1') or soup.find('h2')
            if not title:
                print(f'❌ Não foi possível encontrar o título para {url}')
                return
            title_text = title.get_text(strip=True)
            
            # Extrair conteúdo principal
            content_div = soup.find('div', class_='elementor-widget-theme-post-content') or \
                          soup.find('div', class_='elementor-text-editor') or \
                          soup.find('div', class_='entry-content')
            
            if content_div:
                # Extrair todos os parágrafos, listas e cabeçalhos
                content_elements = content_div.find_all(['p', 'h2', 'h3', 'h4', 'ul', 'ol'])
                
                content_text = []
                for element in content_elements:
                    if element.name in ['h2', 'h3', 'h4']:
                        level = int(element.name[1])
                        content_text.append(f"\n{'#' * level} {element.get_text(strip=True)}\n")
                    elif element.name == 'ol':
                        items = [f"{i+1}. {li.get_text(strip=True)}" for i, li in enumerate(element.find_all('li'))]
                        content_text.append("\n" + "\n".join(items) + "\n")
                    elif element.name == 'ul':
                        items = [f"- {li.get_text(strip=True)}" for li in element.find_all('li')]
                        content_text.append("\n" + "\n".join(items) + "\n")
                    else:
                        content_text.append(element.get_text(strip=True))
                
                full_content = "\n".join(content_text)
            else:
                full_content = "Conteúdo principal não encontrado"
            
            # Criar nome do arquivo
            filename = os.path.join(output_path, sanitize_filename(title_text) + '.md')
            
            # Escrever o conteúdo no arquivo
            with open(filename, 'w', encoding='utf-8') as f:
                f.write(f'# {title_text}\n\n')
                f.write(full_content)
            
            print(f'✅ Conteúdo salvo: {filename}')
    
    except Exception as e:
        print(f'❌ Erro ao processar {url}: {e}')

# Processar cada URL do blog
for blog_url in blog_urls:
    extract_and_save(blog_url)
# Out:
# 🔗 105 URLs encontrados em 13 páginas acessadas.
#
# ✅ Conteúdo salvo: ../Input/Blog\AdTech_ o que é_ Para que serve_ Por que usar essa tecnologia_.md
# ✅ Conteúdo salvo: ../Input/Blog\Quais são as métricas mais importantes para as campanhas de Product Ads_.md
# ✅ Conteúdo salvo: ../Input/Blog\Tempo de resposta no Mercado Livre_ por que é importante_ Como funciona_.md
# ✅ Conteúdo salvo: ../Input/Blog\Novas regras para Loja Oficial no Mercado Livre já estão valendo_.md
# ✅ Conteúdo salvo: ../Input/Blog\Saiba tudo sobre ACOS no Mercado Livre Ads _Guia Completo_.md
# ✅ Conteúdo salvo: ../Input/Blog\Shopee Ads_ o que é_ Como funciona_ Confira nosso Guia completo_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como Proteger Sua Conta no Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Fotos dos produtos no Mercado Livre_ entenda o poder que elas têm_.md
# ✅ Conteúdo salvo: ../Input/Blog\A nova era do marketing_ como a retail media está revolucionando a publicidade_.md
# ✅ Conteúdo salvo: ../Input/Blog\Publicidade em marketplaces_ por que os profissionais de marketing devem olhar para ela_.md
# ✅ Conteúdo salvo: ../Input/Blog\Mercado Livre vai dar 1 milhão em prêmio na Black Friday_.md
# ✅ Conteúdo salvo: ../Input/Blog\Facebook Ads e Google Ads para Mercado Livre_ prós e contras_.md
# ✅ Conteúdo salvo: ../Input/Blog\22 trilhas para vídeos no Mercado Livre para você escolher agora_.md
# ✅ Conteúdo salvo: ../Input/Blog\Você está preparado para crescer no Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Fulfillment no Mercado Livre_ como funciona_ Por que ele é importante_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como transformar perguntas em vendas no Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como usar o Retorno sobre Conteúdo para justificar investimentos em Publicidade Digital_.md
# ✅ Conteúdo salvo: ../Input/Blog\Tráfego pago_ 5 dicas para conseguir mais visitas no seu E-commerce_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como criar descrições para os anúncios de produtos no Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\O que é jornada de compra do cliente_ E Como usá-la em uma estratégia de marketing_.md
# ✅ Conteúdo salvo: ../Input/Blog\Black Friday_ 13 dicas infalíveis para turbinar as vendas do seu Ecommerce_.md
# ✅ Conteúdo salvo: ../Input/Blog\Simulador de custos Mercado Livre_ veja como usar_.md
# ✅ Conteúdo salvo: ../Input/Blog\Anúncio Premium no Mercado Livre_ quando usar_.md
# ✅ Conteúdo salvo: ../Input/Blog\Resposta automática no Mercado Livre_ quando usar_.md
# ✅ Conteúdo salvo: ../Input/Blog\Envios no prazo_ saiba porque isso é importante para suas vendas no Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Saiba tudo sobre mensagem automática no_ Mercado Livre_ Vale mesmo a pena_.md
# ✅ Conteúdo salvo: ../Input/Blog\BPP Mercado Livre _ Programa de Proteção de Marca_ o que é_ Como usar_.md
# ✅ Conteúdo salvo: ../Input/Blog\Principais motivos para queda nas vendas dentro do Mercado livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Quando e quais produtos você deve anunciar no Mercado Livre com o Product Ads_.md
# ✅ Conteúdo salvo: ../Input/Blog\Loja Oficial no Mercado Livre_ Uma Estratégia Assertiva em Branding_.md
# ✅ Conteúdo salvo: ../Input/Blog\Crie Anúncios de Kits no Mercado Livre para aumentar suas vendas_.md
# ✅ Conteúdo salvo: ../Input/Blog\Variações de produtos no mercado livre_ como utilizá-las corretamente_.md
# ✅ Conteúdo salvo: ../Input/Blog\Estratégia de vendas Mercado Livre_ veja 03 maneiras para escalar suas vendas_.md
# ✅ Conteúdo salvo: ../Input/Blog\Publicidade Mercado Livre_ O que é_ Como fazer_.md
# ✅ Conteúdo salvo: ../Input/Blog\Por que meu anúncio não vende no Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Mercado Livre Ads vale a pena_ Quais as vantagens_ Compensa investir nessa solução de publicidade_.md
# ✅ Conteúdo salvo: ../Input/Blog\Frete e Parcelamento_ qual a influência nas compras online_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como usar ferramentas de Inteligência Artificial na jornada de vendas em Marketplaces_.md
# ✅ Conteúdo salvo: ../Input/Blog\Entenda a métrica de vendas assistidas no painel de publicidade do Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Devo pausar os anúncios do Mercado Livre_ Quais as consequências_.md
# ✅ Conteúdo salvo: ../Input/Blog\Datas especiais no Mercado Livre_ Já otimizou seus anúncios de Ads_.md
# ✅ Conteúdo salvo: ../Input/Blog\Conheça a Central de Parceiros do Mercado Livre e descubra as melhores soluções para vender na plataforma_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como vender mais no Mercado Livre_ É possível fazer isso com eficiência_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como definir o orçamento diário para as campanhas de Product Ads_.md
# ✅ Conteúdo salvo: ../Input/Blog\Curva ABC de vendas nas campanhas de Product Ads_.md
# ✅ Conteúdo salvo: ../Input/Blog\Mídia Programática_ o que é_ Quando usar e quais as vantagens_.md
# ✅ Conteúdo salvo: ../Input/Blog\O que pode editar nos anúncios no Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Marketing de Varejo já é realidade no Brasil_ Entenda como ela funciona e porque adotar essa estratégia_.md
# ✅ Conteúdo salvo: ../Input/Blog\Quais são as tarifas para vender no Mercado Livre_ Confira as taxas que a plataforma cobra_.md
# ✅ Conteúdo salvo: ../Input/Blog\Estoque virtual e a ilusão do estoque infinito_ Por que vendedores quebram no marketplace_.md
# ✅ Conteúdo salvo: ../Input/Blog\69_ das grandes marcas optam pelo Mercado Livre em suas campanhas de Retail Media_.md
# ✅ Conteúdo salvo: ../Input/Blog\Ajuste de preços automático no Mercado Livre_ análise completa_.md
# ✅ Conteúdo salvo: ../Input/Blog\Guia Completo de SEO para Mercado Livre_ Otimize seus anúncios e aumente suas vendas_.md
# ✅ Conteúdo salvo: ../Input/Blog\Tendências no Mercado Livre_ Como Utilizá-las para Melhorar suas Vendas_.md
# ✅ Conteúdo salvo: ../Input/Blog\O que é Product Ads_ Como funciona_ Qual preço vou pagar_.md
# ✅ Conteúdo salvo: ../Input/Blog\Palavras chave no Mercado Livre_ Confira 5 dicas para aumentar as vendas_.md
# ✅ Conteúdo salvo: ../Input/Blog\Catálogo Mercado Livre_ o que é_ Como funciona_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como aumentar as vendas no Mercado Livre_ Confira 12 dicas comprovadas_.md
# ✅ Conteúdo salvo: ../Input/Blog\Full funnel_ como usar essa estratégia nas vendas online_.md
# ✅ Conteúdo salvo: ../Input/Blog\Saiba tudo sobre anúncio pausado Mercado Livre_ o que é_ O que isso significa_.md
# ✅ Conteúdo salvo: ../Input/Blog\Publicidade Digital em redes de varejo_ porque ela será o principal canal on-line_.md
# ✅ Conteúdo salvo: ../Input/Blog\Check-list com 9 preparativos para vender na Black Friday do Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Retail Media e AdTech_ qual a relação entre elas_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como alterar o preço de um produto no Mercado Livre sem prejudicar as vendas_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como Fazer Bons Títulos de Anúncio no Mercado Livre_ 07 dicas infalíveis_.md
# ✅ Conteúdo salvo: ../Input/Blog\O que é Mercado Livre Ads_ Para que serve_ Como funciona_.md
# ✅ Conteúdo salvo: ../Input/Blog\Criar e editar vídeos no CapCut_ confira nosso tutorial com dicas exclusivas_.md
# ❌ Não foi possível encontrar o título para https://www.conectaads.com.br/conteudos/
# ✅ Conteúdo salvo: ../Input/Blog\Segmentação avançada no marketing digital_ por que fazer_.md
# ✅ Conteúdo salvo: ../Input/Blog\A mídia de varejo está em alta_ é hora de usar Retail Media para publicidade paga_.md
# ✅ Conteúdo salvo: ../Input/Blog\Os cookies na publicidade digital e a contribuição do Retail Media_.md
# ✅ Conteúdo salvo: ../Input/Blog\5 Tipos de anúncios no Mercado Livre_ Guia Completo_.md
# ✅ Conteúdo salvo: ../Input/Blog\Anúncio patrocinado no Mercado Livre_ tudo que você precisa saber para aumentar as suas vendas_.md
# ✅ Conteúdo salvo: ../Input/Blog\Aumentar Visibilidade no Mercado Livre_ Dicas e Estratégias_.md
# ✅ Conteúdo salvo: ../Input/Blog\Branding no Mercado Livre_ dá pra fazer_ Como funciona_ Confira nosso Guia Completo_.md
# ✅ Conteúdo salvo: ../Input/Blog\Clips Mercado Livre_ ferramenta de vídeos que promete aumentar 5x o número de visitas_.md
# ✅ Conteúdo salvo: ../Input/Blog\Vídeos curtos no Mercado Livre_ o que são_ Como utilizar para vender mais_.md
# ✅ Conteúdo salvo: ../Input/Blog\Por que você não deve deixar de ir ao Mercado Livre Experience _Meli XP__.md
# ✅ Conteúdo salvo: ../Input/Blog\Como criar anúncios que vendem muito no Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Modo férias no Mercado Livre_ Saiba o que fazer para não perder vendas_.md
# ✅ Conteúdo salvo: ../Input/Blog\Ficha Técnica nos Anúncios do Mercado Livre_ não deixe em branco_.md
# ✅ Conteúdo salvo: ../Input/Blog\ASSESSORIA MERCADO LIVRE COM CERTIFICAÇÃO PLATINUMOtimize suas Vendas no Mercado Livre comCampanhas InteligenteseAltamente Rentáveis.md
# ✅ Conteúdo salvo: ../Input/Blog\Venda seus produtos para os compradores certos no Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Qual a 3ª onda da Publicidade Digital_.md
# ✅ Conteúdo salvo: ../Input/Blog\Simulador de custos Mercado Pago_ veja como usar_.md
# ✅ Conteúdo salvo: ../Input/Blog\14 dicas para vender mais no Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Retail media_ o que é_ Como funciona_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como ser MercadoLíder Platinum no Mercado Livre_ Quais as vantagens_.md
# ✅ Conteúdo salvo: ../Input/Blog\Mercado Ads Academy_ quem deve fazer o curso de Mercado Ads_.md
# ✅ Conteúdo salvo: ../Input/Blog\Qual a importância do registro de marca _INPI_ para sua Loja Oficial no Mercado Livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Consultoria Mercado Livre_ o que faz_ Quais as melhores_.md
# ✅ Conteúdo salvo: ../Input/Blog\First party Data_ porque atualmente é tão importante na sua estratégia de marketing_.md
# ✅ Conteúdo salvo: ../Input/Blog\5 fatores que farão a Mídia de Varejo crescer 60_ até 2027_.md
# ✅ Conteúdo salvo: ../Input/Blog\Full-Funnel no Mercado Ads_ o que é_ Por que é importante_.md
# ✅ Conteúdo salvo: ../Input/Blog\O que é Mercado Livre Ads como funciona e para que serve_.md
# ✅ Conteúdo salvo: ../Input/Blog\Publicidade Tradicional_ Marketing Digital e Retail Media_ Quem ganha na era do E-commerce_.md
# ✅ Conteúdo salvo: ../Input/Blog\10 dicas para evitar que suas reclamações aumentem no Mercado livre_.md
# ✅ Conteúdo salvo: ../Input/Blog\Ruptura de estoque nos anúncios do Mercado Livre_ não deixe isso acontecer_.md
# ✅ Conteúdo salvo: ../Input/Blog\Por que meus anúncios não aparecem no Mercado Livre_ Veja o que pode estar acontecendo_.md
# ✅ Conteúdo salvo: ../Input/Blog\Reputação no Mercado Livre_ por que ela é importante_.md
# ✅ Conteúdo salvo: ../Input/Blog\Marketplaces são os novos mecanismos de busca de produtos_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como criar seus Clips no Mercado Livre_ Confira algumas dicas que vão impulsionar seus produtos_.md
# ✅ Conteúdo salvo: ../Input/Blog\Retail media não é mais tendência_ é um fato_.md
# ✅ Conteúdo salvo: ../Input/Blog\Como ficar verde no Mercado Livre_ Veja o que fazer para melhorar a reputação_.md
# ✅ Conteúdo salvo: ../Input/Blog\Taxa de conversão_ Por que ela é importante em suas vendas no Mercado Livre_.md

# %%
import requests
from bs4 import BeautifulSoup
import os

# URL base do blog
base_url = 'https://www.conectaads.com.br/conteudos/'
pagina = 1
blog_urls = set()  # Usamos um conjunto para evitar duplicatas
paginas_acessadas = 0  # Contador de páginas acessadas

# Pasta de saída para salvar os arquivos Markdown
output_path = "../Input/Blog"
os.makedirs(output_path, exist_ok=True)

def sanitize_filename(name):
    """ Remove caracteres inválidos do nome do arquivo. """
    return "".join(c if c.isalnum() or c in (" ", "-", "_") else "_" for c in name)

# Coletar todas as URLs do blog paginando até a última página
print("🔍 Iniciando coleta de URLs do blog...")
while True:
    # Construir a URL paginada
    url = f'{base_url}page/{pagina}/' if pagina > 1 else base_url
    print(f"📄 Acessando página {pagina}: {url}")
    response = requests.get(url)

    # Verificar se a solicitação foi bem-sucedida
    if response.status_code != 200:
        print(f'❌ Falha ao acessar a página {pagina}. Código de status: {response.status_code}')
        break

    # Atualiza o número de páginas acessadas
    paginas_acessadas += 1

    # Analisar o conteúdo HTML
    soup = BeautifulSoup(response.content, 'html.parser')

    # Encontrar todos os links de postagens
    links = soup.find_all('a', href=True)

    # Filtrar URLs que parecem ser de conteúdos do blog
    excluidos = ['home', 'contato', 'lgpd', 'blog', 'quem-somos', '/page/', 'categoria']
    novos_links = [
        link['href'] for link in links
        if link['href'].startswith('https://www.conectaads.com.br/') and
        not any(ex in link['href'] for ex in excluidos)
    ]

    # Adicionar ao conjunto de URLs
    blog_urls.update(novos_links)
    print(f"✅ Encontrados {len(novos_links)} links na página {pagina}")

    # Encontrar o link da próxima página corretamente pelo "href"
    next_page_link = soup.find('a', href=lambda href: href and "/page/" in href)

    # Se não houver próxima página, parar o loop
    if not next_page_link:
        print("⏹️ Última página encontrada")
        break

    pagina += 1  # Ir para a próxima página

# Exibir o total de URLs encontrados e páginas acessadas
print(f"\n🔗 Total de {len(blog_urls)} URLs encontrados em {paginas_acessadas} páginas acessadas.\n")
print("⏳ Iniciando extração de conteúdos...\n")

def extract_and_save(url):
    try:
        print(f"🌐 Acessando URL: {url}")
        page = requests.get(url)
        if page.status_code == 200:
            soup = BeautifulSoup(page.content, 'html.parser')
            
            # Extrair título
            title = soup.find('h1') or soup.find('h2')
            if not title:
                print(f'❌ Não foi possível encontrar o título para {url}')
                return
            title_text = title.get_text(strip=True)
            
            # Extrair conteúdo principal
            content_div = soup.find('div', class_='elementor-widget-theme-post-content') or \
                          soup.find('div', class_='elementor-text-editor') or \
                          soup.find('div', class_='entry-content')
            
            if content_div:
                # Extrair todos os parágrafos, listas e cabeçalhos
                content_elements = content_div.find_all(['p', 'h2', 'h3', 'h4', 'ul', 'ol', 'strong'])
                
                content_text = []
                for element in content_elements:
                    if element.name in ['h2', 'h3', 'h4']:
                        level = int(element.name[1])
                        content_text.append(f"\n{'#' * level} {element.get_text(strip=True)}\n")
                    elif element.name == 'ol':
                        items = [f"{i+1}. {li.get_text(strip=True)}" for i, li in enumerate(element.find_all('li'))]
                        content_text.append("\n" + "\n".join(items) + "\n")
                    elif element.name == 'ul':
                        items = [f"- {li.get_text(strip=True)}" for li in element.find_all('li')]
                        content_text.append("\n" + "\n".join(items) + "\n")
                    elif element.name == 'strong':
                        # Adiciona espaços antes e depois do texto em negrito
                        content_text.append(f" **{element.get_text(strip=True)}** ")
                    else:
                        # Para parágrafos normais, processamos cada nó individualmente
                        for content in element.contents:
                            if content.name == 'strong':
                                content_text.append(f" **{content.get_text(strip=True)}** ")
                            elif content.name is None:  # Texto normal
                                content_text.append(str(content).replace('\n', ' ').strip())
                
                full_content = "".join(content_text)
                # Remove espaços múltiplos e limpa a formatação
                full_content = " ".join(full_content.split())
            else:
                full_content = "Conteúdo principal não encontrado"
                print(f"⚠️ Conteúdo não encontrado em {url}")
            
            # Criar nome do arquivo
            filename = os.path.join(output_path, sanitize_filename(title_text) + '.md')
            
            # Escrever o conteúdo no arquivo
            with open(filename, 'w', encoding='utf-8') as f:
                f.write(f'# {title_text}\n\n')
                f.write(full_content)
                # Adicionar URL de origem no final do arquivo
                f.write(f'\n\n---\n\nFonte: [{url}]({url})')
            
            print(f'✅ Conteúdo salvo: {filename}\n')
    
    except Exception as e:
        print(f'❌ Erro ao processar {url}: {e}\n')

# Processar cada URL do blog
print(f"📝 Iniciando processamento de {len(blog_urls)} artigos...\n")
for i, blog_url in enumerate(blog_urls, 1):
    print(f"📌 Processando artigo {i}/{len(blog_urls)}")
    extract_and_save(blog_url)

print("\n✨ Processo concluído! Todos os artigos foram salvos.")
# Out:
# 🔍 Iniciando coleta de URLs do blog...
# 📄 Acessando página 1: https://www.conectaads.com.br/conteudos/
# ✅ Encontrados 19 links na página 1
# 📄 Acessando página 2: https://www.conectaads.com.br/conteudos/page/2/
# ✅ Encontrados 18 links na página 2
# 📄 Acessando página 3: https://www.conectaads.com.br/conteudos/page/3/
# ✅ Encontrados 20 links na página 3
# 📄 Acessando página 4: https://www.conectaads.com.br/conteudos/page/4/
# ✅ Encontrados 18 links na página 4
# 📄 Acessando página 5: https://www.conectaads.com.br/conteudos/page/5/
# ✅ Encontrados 20 links na página 5
# 📄 Acessando página 6: https://www.conectaads.com.br/conteudos/page/6/
# ✅ Encontrados 20 links na página 6
# 📄 Acessando página 7: https://www.conectaads.com.br/conteudos/page/7/
# ✅ Encontrados 20 links na página 7
# 📄 Acessando página 8: https://www.conectaads.com.br/conteudos/page/8/
# ✅ Encontrados 20 links na página 8
# 📄 Acessando página 9: https://www.conectaads.com.br/conteudos/page/9/
# ✅ Encontrados 20 links na página 9
# 📄 Acessando página 10: https://www.conectaads.com.br/conteudos/page/10/
# ✅ Encontrados 20 links na página 10
# 📄 Acessando página 11: https://www.conectaads.com.br/conteudos/page/11/
# ✅ Encontrados 20 links na página 11
# 📄 Acessando página 12: https://www.conectaads.com.br/conteudos/page/12/
# ✅ Encontrados 14 links na página 12
# 📄 Acessando página 13: https://www.conectaads.com.br/conteudos/page/13/
# ✅ Encontrados 1 links na página 13
# ⏹️ Última página encontrada
#
# 🔗 Total de 105 URLs encontrados em 13 páginas acessadas.
#
# ⏳ Iniciando extração de conteúdos...
#
# 📝 Iniciando processamento de 105 artigos...
#
# 📌 Processando artigo 1/105
# 🌐 Acessando URL: https://www.conectaads.com.br/adtech-o-que-e/
# ✅ Conteúdo salvo: ../Input/Blog\AdTech_ o que é_ Para que serve_ Por que usar essa tecnologia_.md
#
# 📌 Processando artigo 2/105
# 🌐 Acessando URL: https://www.conectaads.com.br/metricas-em-campanhas-de-product-ads/
# ✅ Conteúdo salvo: ../Input/Blog\Quais são as métricas mais importantes para as campanhas de Product Ads_.md
#
# 📌 Processando artigo 3/105
# 🌐 Acessando URL: https://www.conectaads.com.br/tempo-de-resposta-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Tempo de resposta no Mercado Livre_ por que é importante_ Como funciona_.md
#
# 📌 Processando artigo 4/105
# 🌐 Acessando URL: https://www.conectaads.com.br/novas-regras-para-loja-oficial-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Novas regras para Loja Oficial no Mercado Livre já estão valendo_.md
#
# 📌 Processando artigo 5/105
# 🌐 Acessando URL: https://www.conectaads.com.br/acos-mercado-livre-ads/
# ✅ Conteúdo salvo: ../Input/Blog\Saiba tudo sobre ACOS no Mercado Livre Ads _Guia Completo_.md
#
# 📌 Processando artigo 6/105
# 🌐 Acessando URL: https://www.conectaads.com.br/shopee-ads-o-que-e/
# ✅ Conteúdo salvo: ../Input/Blog\Shopee Ads_ o que é_ Como funciona_ Confira nosso Guia completo_.md
#
# 📌 Processando artigo 7/105
# 🌐 Acessando URL: https://www.conectaads.com.br/proteger-sua-conta-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Como Proteger Sua Conta no Mercado Livre_.md
#
# 📌 Processando artigo 8/105
# 🌐 Acessando URL: https://www.conectaads.com.br/fotos-de-produtos-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Fotos dos produtos no Mercado Livre_ entenda o poder que elas têm_.md
#
# 📌 Processando artigo 9/105
# 🌐 Acessando URL: https://www.conectaads.com.br/retail-media-publicidade/
# ✅ Conteúdo salvo: ../Input/Blog\A nova era do marketing_ como a retail media está revolucionando a publicidade_.md
#
# 📌 Processando artigo 10/105
# 🌐 Acessando URL: https://www.conectaads.com.br/publicidade-em-marketplaces/
# ✅ Conteúdo salvo: ../Input/Blog\Publicidade em marketplaces_ por que os profissionais de marketing devem olhar para ela_.md
#
# 📌 Processando artigo 11/105
# 🌐 Acessando URL: https://www.conectaads.com.br/campanha-black-friday-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Mercado Livre vai dar 1 milhão em prêmio na Black Friday_.md
#
# 📌 Processando artigo 12/105
# 🌐 Acessando URL: https://www.conectaads.com.br/facebook-ads-para-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Facebook Ads e Google Ads para Mercado Livre_ prós e contras_.md
#
# 📌 Processando artigo 13/105
# 🌐 Acessando URL: https://www.conectaads.com.br/trilhas-para-videos/
# ✅ Conteúdo salvo: ../Input/Blog\22 trilhas para vídeos no Mercado Livre para você escolher agora_.md
#
# 📌 Processando artigo 14/105
# 🌐 Acessando URL: https://www.conectaads.com.br/preparado-para-crescer-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Você está preparado para crescer no Mercado Livre_.md
#
# 📌 Processando artigo 15/105
# 🌐 Acessando URL: https://www.conectaads.com.br/fulfillment-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Fulfillment no Mercado Livre_ como funciona_ Por que ele é importante_.md
#
# 📌 Processando artigo 16/105
# 🌐 Acessando URL: https://www.conectaads.com.br/perguntas-no-mercado-livre-vender-mais/
# ✅ Conteúdo salvo: ../Input/Blog\Como transformar perguntas em vendas no Mercado Livre_.md
#
# 📌 Processando artigo 17/105
# 🌐 Acessando URL: https://www.conectaads.com.br/retorno-sobre-conteudo-conceitos/
# ✅ Conteúdo salvo: ../Input/Blog\Como usar o Retorno sobre Conteúdo para justificar investimentos em Publicidade Digital_.md
#
# 📌 Processando artigo 18/105
# 🌐 Acessando URL: https://www.conectaads.com.br/trafego-pago-dicas/
# ✅ Conteúdo salvo: ../Input/Blog\Tráfego pago_ 5 dicas para conseguir mais visitas no seu E-commerce_.md
#
# 📌 Processando artigo 19/105
# 🌐 Acessando URL: https://www.conectaads.com.br/descricao-de-anuncio-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Como criar descrições para os anúncios de produtos no Mercado Livre_.md
#
# 📌 Processando artigo 20/105
# 🌐 Acessando URL: https://www.conectaads.com.br/jornada-de-compra-cliente/
# ✅ Conteúdo salvo: ../Input/Blog\O que é jornada de compra do cliente_ E Como usá-la em uma estratégia de marketing_.md
#
# 📌 Processando artigo 21/105
# 🌐 Acessando URL: https://www.conectaads.com.br/black-friday-como-vender-mais/
# ✅ Conteúdo salvo: ../Input/Blog\Black Friday_ 13 dicas infalíveis para turbinar as vendas do seu Ecommerce_.md
#
# 📌 Processando artigo 22/105
# 🌐 Acessando URL: https://www.conectaads.com.br/simulador-de-custos-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Simulador de custos Mercado Livre_ veja como usar_.md
#
# 📌 Processando artigo 23/105
# 🌐 Acessando URL: https://www.conectaads.com.br/anuncio-premium-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Anúncio Premium no Mercado Livre_ quando usar_.md
#
# 📌 Processando artigo 24/105
# 🌐 Acessando URL: https://www.conectaads.com.br/resposta-automatica-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Resposta automática no Mercado Livre_ quando usar_.md
#
# 📌 Processando artigo 25/105
# 🌐 Acessando URL: https://www.conectaads.com.br/envios-no-prazo-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Envios no prazo_ saiba porque isso é importante para suas vendas no Mercado Livre_.md
#
# 📌 Processando artigo 26/105
# 🌐 Acessando URL: https://www.conectaads.com.br/mensagem-automatica-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Saiba tudo sobre mensagem automática no_ Mercado Livre_ Vale mesmo a pena_.md
#
# 📌 Processando artigo 27/105
# 🌐 Acessando URL: https://www.conectaads.com.br/bpp-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\BPP Mercado Livre _ Programa de Proteção de Marca_ o que é_ Como usar_.md
#
# 📌 Processando artigo 28/105
# 🌐 Acessando URL: https://www.conectaads.com.br/vendas-cairam-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Principais motivos para queda nas vendas dentro do Mercado livre_.md
#
# 📌 Processando artigo 29/105
# 🌐 Acessando URL: https://www.conectaads.com.br/quando-anunciar-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Quando e quais produtos você deve anunciar no Mercado Livre com o Product Ads_.md
#
# 📌 Processando artigo 30/105
# 🌐 Acessando URL: https://www.conectaads.com.br/loja-oficial-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Loja Oficial no Mercado Livre_ Uma Estratégia Assertiva em Branding_.md
#
# 📌 Processando artigo 31/105
# 🌐 Acessando URL: https://www.conectaads.com.br/anuncios-de-kits-de-produtos-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Crie Anúncios de Kits no Mercado Livre para aumentar suas vendas_.md
#
# 📌 Processando artigo 32/105
# 🌐 Acessando URL: https://www.conectaads.com.br/variacoes-de-produtos-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Variações de produtos no mercado livre_ como utilizá-las corretamente_.md
#
# 📌 Processando artigo 33/105
# 🌐 Acessando URL: https://www.conectaads.com.br/estrategia-de-vendas-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Estratégia de vendas Mercado Livre_ veja 03 maneiras para escalar suas vendas_.md
#
# 📌 Processando artigo 34/105
# 🌐 Acessando URL: https://www.conectaads.com.br/publicidade-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Publicidade Mercado Livre_ O que é_ Como fazer_.md
#
# 📌 Processando artigo 35/105
# 🌐 Acessando URL: https://www.conectaads.com.br/anuncio-nao-vende-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Por que meu anúncio não vende no Mercado Livre_.md
#
# 📌 Processando artigo 36/105
# 🌐 Acessando URL: https://www.conectaads.com.br/mercado-ads-vale-a-pena/
# ✅ Conteúdo salvo: ../Input/Blog\Mercado Livre Ads vale a pena_ Quais as vantagens_ Compensa investir nessa solução de publicidade_.md
#
# 📌 Processando artigo 37/105
# 🌐 Acessando URL: https://www.conectaads.com.br/frete-e-parcelamento-compras-online/
# ✅ Conteúdo salvo: ../Input/Blog\Frete e Parcelamento_ qual a influência nas compras online_.md
#
# 📌 Processando artigo 38/105
# 🌐 Acessando URL: https://www.conectaads.com.br/ferramentas-de-ia-para-marketplaces/
# ✅ Conteúdo salvo: ../Input/Blog\Como usar ferramentas de Inteligência Artificial na jornada de vendas em Marketplaces_.md
#
# 📌 Processando artigo 39/105
# 🌐 Acessando URL: https://www.conectaads.com.br/metrica-de-vendas-assistidas-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Entenda a métrica de vendas assistidas no painel de publicidade do Mercado Livre_.md
#
# 📌 Processando artigo 40/105
# 🌐 Acessando URL: https://www.conectaads.com.br/pausar-anuncios-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Devo pausar os anúncios do Mercado Livre_ Quais as consequências_.md
#
# 📌 Processando artigo 41/105
# 🌐 Acessando URL: https://www.conectaads.com.br/datas-especiais-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Datas especiais no Mercado Livre_ Já otimizou seus anúncios de Ads_.md
#
# 📌 Processando artigo 42/105
# 🌐 Acessando URL: https://www.conectaads.com.br/central-de-parceiros-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Conheça a Central de Parceiros do Mercado Livre e descubra as melhores soluções para vender na plataforma_.md
#
# 📌 Processando artigo 43/105
# 🌐 Acessando URL: https://www.conectaads.com.br/como-vender-mais-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Como vender mais no Mercado Livre_ É possível fazer isso com eficiência_.md
#
# 📌 Processando artigo 44/105
# 🌐 Acessando URL: https://www.conectaads.com.br/orcamento-diario-product-ads/
# ✅ Conteúdo salvo: ../Input/Blog\Como definir o orçamento diário para as campanhas de Product Ads_.md
#
# 📌 Processando artigo 45/105
# 🌐 Acessando URL: https://www.conectaads.com.br/curva-abc-em-product-ads/
# ✅ Conteúdo salvo: ../Input/Blog\Curva ABC de vendas nas campanhas de Product Ads_.md
#
# 📌 Processando artigo 46/105
# 🌐 Acessando URL: https://www.conectaads.com.br/midia-programatica-o-que-e/
# ✅ Conteúdo salvo: ../Input/Blog\Mídia Programática_ o que é_ Quando usar e quais as vantagens_.md
#
# 📌 Processando artigo 47/105
# 🌐 Acessando URL: https://www.conectaads.com.br/editar-um-anuncio-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\O que pode editar nos anúncios no Mercado Livre_.md
#
# 📌 Processando artigo 48/105
# 🌐 Acessando URL: https://www.conectaads.com.br/marketing-de-varejo/
# ✅ Conteúdo salvo: ../Input/Blog\Marketing de Varejo já é realidade no Brasil_ Entenda como ela funciona e porque adotar essa estratégia_.md
#
# 📌 Processando artigo 49/105
# 🌐 Acessando URL: https://www.conectaads.com.br/tarifas-taxas-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Quais são as tarifas para vender no Mercado Livre_ Confira as taxas que a plataforma cobra_.md
#
# 📌 Processando artigo 50/105
# 🌐 Acessando URL: https://www.conectaads.com.br/estoque-virtual-vendas-online/
# ✅ Conteúdo salvo: ../Input/Blog\Estoque virtual e a ilusão do estoque infinito_ Por que vendedores quebram no marketplace_.md
#
# 📌 Processando artigo 51/105
# 🌐 Acessando URL: https://www.conectaads.com.br/grandes-marcas-escolhem-o-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\69_ das grandes marcas optam pelo Mercado Livre em suas campanhas de Retail Media_.md
#
# 📌 Processando artigo 52/105
# 🌐 Acessando URL: https://www.conectaads.com.br/precificacao-automatica-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Ajuste de preços automático no Mercado Livre_ análise completa_.md
#
# 📌 Processando artigo 53/105
# 🌐 Acessando URL: https://www.conectaads.com.br/seo-para-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Guia Completo de SEO para Mercado Livre_ Otimize seus anúncios e aumente suas vendas_.md
#
# 📌 Processando artigo 54/105
# 🌐 Acessando URL: https://www.conectaads.com.br/tendencias-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Tendências no Mercado Livre_ Como Utilizá-las para Melhorar suas Vendas_.md
#
# 📌 Processando artigo 55/105
# 🌐 Acessando URL: https://www.conectaads.com.br/product-ads/
# ✅ Conteúdo salvo: ../Input/Blog\O que é Product Ads_ Como funciona_ Qual preço vou pagar_.md
#
# 📌 Processando artigo 56/105
# 🌐 Acessando URL: https://www.conectaads.com.br/palavras-chave-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Palavras chave no Mercado Livre_ Confira 5 dicas para aumentar as vendas_.md
#
# 📌 Processando artigo 57/105
# 🌐 Acessando URL: https://www.conectaads.com.br/anuncio-catalogo-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Catálogo Mercado Livre_ o que é_ Como funciona_.md
#
# 📌 Processando artigo 58/105
# 🌐 Acessando URL: https://www.conectaads.com.br/como-aumentar-as-vendas-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Como aumentar as vendas no Mercado Livre_ Confira 12 dicas comprovadas_.md
#
# 📌 Processando artigo 59/105
# 🌐 Acessando URL: https://www.conectaads.com.br/full-funnel-marketing-funil-completo/
# ✅ Conteúdo salvo: ../Input/Blog\Full funnel_ como usar essa estratégia nas vendas online_.md
#
# 📌 Processando artigo 60/105
# 🌐 Acessando URL: https://www.conectaads.com.br/anuncio-pausado-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Saiba tudo sobre anúncio pausado Mercado Livre_ o que é_ O que isso significa_.md
#
# 📌 Processando artigo 61/105
# 🌐 Acessando URL: https://www.conectaads.com.br/publicidade-digital-redes-de-varejo/
# ✅ Conteúdo salvo: ../Input/Blog\Publicidade Digital em redes de varejo_ porque ela será o principal canal on-line_.md
#
# 📌 Processando artigo 62/105
# 🌐 Acessando URL: https://www.conectaads.com.br/preparar-vender-black-friday-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Check-list com 9 preparativos para vender na Black Friday do Mercado Livre_.md
#
# 📌 Processando artigo 63/105
# 🌐 Acessando URL: https://www.conectaads.com.br/retail-media-e-adtech/
# ✅ Conteúdo salvo: ../Input/Blog\Retail Media e AdTech_ qual a relação entre elas_.md
#
# 📌 Processando artigo 64/105
# 🌐 Acessando URL: https://www.conectaads.com.br/alterar-o-preco-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Como alterar o preço de um produto no Mercado Livre sem prejudicar as vendas_.md
#
# 📌 Processando artigo 65/105
# 🌐 Acessando URL: https://www.conectaads.com.br/titulos-anuncios-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Como Fazer Bons Títulos de Anúncio no Mercado Livre_ 07 dicas infalíveis_.md
#
# 📌 Processando artigo 66/105
# 🌐 Acessando URL: https://www.conectaads.com.br/mercado-livre-ads/
# ✅ Conteúdo salvo: ../Input/Blog\O que é Mercado Livre Ads_ Para que serve_ Como funciona_.md
#
# 📌 Processando artigo 67/105
# 🌐 Acessando URL: https://www.conectaads.com.br/capcut-criar-editar-videos/
# ✅ Conteúdo salvo: ../Input/Blog\Criar e editar vídeos no CapCut_ confira nosso tutorial com dicas exclusivas_.md
#
# 📌 Processando artigo 68/105
# 🌐 Acessando URL: https://www.conectaads.com.br/conteudos/
# ❌ Não foi possível encontrar o título para https://www.conectaads.com.br/conteudos/
# 📌 Processando artigo 69/105
# 🌐 Acessando URL: https://www.conectaads.com.br/segmentacao-avancada/
# ✅ Conteúdo salvo: ../Input/Blog\Segmentação avançada no marketing digital_ por que fazer_.md
#
# 📌 Processando artigo 70/105
# 🌐 Acessando URL: https://www.conectaads.com.br/midia-de-varejo-em-alta/
# ✅ Conteúdo salvo: ../Input/Blog\A mídia de varejo está em alta_ é hora de usar Retail Media para publicidade paga_.md
#
# 📌 Processando artigo 71/105
# 🌐 Acessando URL: https://www.conectaads.com.br/cookies-publicidade-digital/
# ✅ Conteúdo salvo: ../Input/Blog\Os cookies na publicidade digital e a contribuição do Retail Media_.md
#
# 📌 Processando artigo 72/105
# 🌐 Acessando URL: https://www.conectaads.com.br/tipos-de-anuncios-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\5 Tipos de anúncios no Mercado Livre_ Guia Completo_.md
#
# 📌 Processando artigo 73/105
# 🌐 Acessando URL: https://www.conectaads.com.br/anuncio-patrocinado-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Anúncio patrocinado no Mercado Livre_ tudo que você precisa saber para aumentar as suas vendas_.md
#
# 📌 Processando artigo 74/105
# 🌐 Acessando URL: https://www.conectaads.com.br/aumentar-visibilidade-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Aumentar Visibilidade no Mercado Livre_ Dicas e Estratégias_.md
#
# 📌 Processando artigo 75/105
# 🌐 Acessando URL: https://www.conectaads.com.br/branding-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Branding no Mercado Livre_ dá pra fazer_ Como funciona_ Confira nosso Guia Completo_.md
#
# 📌 Processando artigo 76/105
# 🌐 Acessando URL: https://www.conectaads.com.br/clips-mercado-livre-videos/
# ✅ Conteúdo salvo: ../Input/Blog\Clips Mercado Livre_ ferramenta de vídeos que promete aumentar 5x o número de visitas_.md
#
# 📌 Processando artigo 77/105
# 🌐 Acessando URL: https://www.conectaads.com.br/videos-curtos-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Vídeos curtos no Mercado Livre_ o que são_ Como utilizar para vender mais_.md
#
# 📌 Processando artigo 78/105
# 🌐 Acessando URL: https://www.conectaads.com.br/meli-xp-mercado-livre-experience/
# ✅ Conteúdo salvo: ../Input/Blog\Por que você não deve deixar de ir ao Mercado Livre Experience _Meli XP__.md
#
# 📌 Processando artigo 79/105
# 🌐 Acessando URL: https://www.conectaads.com.br/criar-anuncios-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Como criar anúncios que vendem muito no Mercado Livre_.md
#
# 📌 Processando artigo 80/105
# 🌐 Acessando URL: https://www.conectaads.com.br/modo-ferias-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Modo férias no Mercado Livre_ Saiba o que fazer para não perder vendas_.md
#
# 📌 Processando artigo 81/105
# 🌐 Acessando URL: https://www.conectaads.com.br/ficha-tecnica-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Ficha Técnica nos Anúncios do Mercado Livre_ não deixe em branco_.md
#
# 📌 Processando artigo 82/105
# 🌐 Acessando URL: https://www.conectaads.com.br/assessoria-mercado-livre/
# ⚠️ Conteúdo não encontrado em https://www.conectaads.com.br/assessoria-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\ASSESSORIA MERCADO LIVRE COM CERTIFICAÇÃO PLATINUMOtimize suas Vendas no Mercado Livre comCampanhas InteligenteseAltamente Rentáveis.md
#
# 📌 Processando artigo 83/105
# 🌐 Acessando URL: https://www.conectaads.com.br/venda-para-compradores-certos-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Venda seus produtos para os compradores certos no Mercado Livre_.md
#
# 📌 Processando artigo 84/105
# 🌐 Acessando URL: https://www.conectaads.com.br/3-onda-da-publicidade-digital/
# ✅ Conteúdo salvo: ../Input/Blog\Qual a 3ª onda da Publicidade Digital_.md
#
# 📌 Processando artigo 85/105
# 🌐 Acessando URL: https://www.conectaads.com.br/simulador-de-custos-mercado-pago/
# ✅ Conteúdo salvo: ../Input/Blog\Simulador de custos Mercado Pago_ veja como usar_.md
#
# 📌 Processando artigo 86/105
# 🌐 Acessando URL: https://www.conectaads.com.br/vender-mais-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\14 dicas para vender mais no Mercado Livre_.md
#
# 📌 Processando artigo 87/105
# 🌐 Acessando URL: https://www.conectaads.com.br/retail-media/
# ✅ Conteúdo salvo: ../Input/Blog\Retail media_ o que é_ Como funciona_.md
#
# 📌 Processando artigo 88/105
# 🌐 Acessando URL: https://www.conectaads.com.br/como-ser-mercadolider-platinum-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Como ser MercadoLíder Platinum no Mercado Livre_ Quais as vantagens_.md
#
# 📌 Processando artigo 89/105
# 🌐 Acessando URL: https://www.conectaads.com.br/curso-mercado-ads-academy/
# ✅ Conteúdo salvo: ../Input/Blog\Mercado Ads Academy_ quem deve fazer o curso de Mercado Ads_.md
#
# 📌 Processando artigo 90/105
# 🌐 Acessando URL: https://www.conectaads.com.br/inpi-registro-de-marca/
# ✅ Conteúdo salvo: ../Input/Blog\Qual a importância do registro de marca _INPI_ para sua Loja Oficial no Mercado Livre_.md
#
# 📌 Processando artigo 91/105
# 🌐 Acessando URL: https://www.conectaads.com.br/consultoria-mercado-livre-o-que-faz/
# ✅ Conteúdo salvo: ../Input/Blog\Consultoria Mercado Livre_ o que faz_ Quais as melhores_.md
#
# 📌 Processando artigo 92/105
# 🌐 Acessando URL: https://www.conectaads.com.br/first-party-data/
# ✅ Conteúdo salvo: ../Input/Blog\First party Data_ porque atualmente é tão importante na sua estratégia de marketing_.md
#
# 📌 Processando artigo 93/105
# 🌐 Acessando URL: https://www.conectaads.com.br/midia-de-varejo/
# ✅ Conteúdo salvo: ../Input/Blog\5 fatores que farão a Mídia de Varejo crescer 60_ até 2027_.md
#
# 📌 Processando artigo 94/105
# 🌐 Acessando URL: https://www.conectaads.com.br/full-funnel-mercado-ads/
# ✅ Conteúdo salvo: ../Input/Blog\Full-Funnel no Mercado Ads_ o que é_ Por que é importante_.md
#
# 📌 Processando artigo 95/105
# 🌐 Acessando URL: https://www.conectaads.com.br/mercado-ads-como-funciona/
# ✅ Conteúdo salvo: ../Input/Blog\O que é Mercado Livre Ads como funciona e para que serve_.md
#
# 📌 Processando artigo 96/105
# 🌐 Acessando URL: https://www.conectaads.com.br/publicidade-marketing-e-retail-media/
# ✅ Conteúdo salvo: ../Input/Blog\Publicidade Tradicional_ Marketing Digital e Retail Media_ Quem ganha na era do E-commerce_.md
#
# 📌 Processando artigo 97/105
# 🌐 Acessando URL: https://www.conectaads.com.br/reclamacoes-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\10 dicas para evitar que suas reclamações aumentem no Mercado livre_.md
#
# 📌 Processando artigo 98/105
# 🌐 Acessando URL: https://www.conectaads.com.br/ruptura-de-estoque-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Ruptura de estoque nos anúncios do Mercado Livre_ não deixe isso acontecer_.md
#
# 📌 Processando artigo 99/105
# 🌐 Acessando URL: https://www.conectaads.com.br/porque-meus-anuncios-nao-aparecem-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Por que meus anúncios não aparecem no Mercado Livre_ Veja o que pode estar acontecendo_.md
#
# 📌 Processando artigo 100/105
# 🌐 Acessando URL: https://www.conectaads.com.br/reputacao-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Reputação no Mercado Livre_ por que ela é importante_.md
#
# 📌 Processando artigo 101/105
# 🌐 Acessando URL: https://www.conectaads.com.br/marketplaces-novo-search/
# ✅ Conteúdo salvo: ../Input/Blog\Marketplaces são os novos mecanismos de busca de produtos_.md
#
# 📌 Processando artigo 102/105
# 🌐 Acessando URL: https://www.conectaads.com.br/criar-clips-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Como criar seus Clips no Mercado Livre_ Confira algumas dicas que vão impulsionar seus produtos_.md
#
# 📌 Processando artigo 103/105
# 🌐 Acessando URL: https://www.conectaads.com.br/retail-media-fabiana-manfredi/
# ✅ Conteúdo salvo: ../Input/Blog\Retail media não é mais tendência_ é um fato_.md
#
# 📌 Processando artigo 104/105
# 🌐 Acessando URL: https://www.conectaads.com.br/ficar-verde-no-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Como ficar verde no Mercado Livre_ Veja o que fazer para melhorar a reputação_.md
#
# 📌 Processando artigo 105/105
# 🌐 Acessando URL: https://www.conectaads.com.br/taxa-de-conversao-vendas-mercado-livre/
# ✅ Conteúdo salvo: ../Input/Blog\Taxa de conversão_ Por que ela é importante em suas vendas no Mercado Livre_.md
#
#
# ✨ Processo concluído! Todos os artigos foram salvos.
